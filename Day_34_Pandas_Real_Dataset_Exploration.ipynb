# %% [markdown]
# #1️⃣ Sabse pehle Real Dataset
#
# ##Aaj ek real-world CSV dataset download/use karna hai.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-baf03832-093c-4ded-ad78-3e2235b890dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-baf03832-093c-4ded-ad78-3e2235b890dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("sales.csv")

# %% [markdown]
# #2️⃣ Dataset Load Hone Ke Baad
#
# #Sabse pehle:
#
# print(df)
#
# ##Lekin large dataset mein pura DataFrame print mat karna.
#
# #Instead:
#
# print(df.head())

# %% [markdown]
# #3️⃣ head()

# %%
df.head()
# Out:
#    sale_id branch         city customer_type  gender  product_name  \
# 0        1      A     New York        Member    Male       Shampoo
# 1        2      B  Los Angeles        Normal  Female      Notebook
# 2        3      A     New York        Member  Female         Apple
# 3        4      A      Chicago        Normal    Male     Detergent
# 4        5      B  Los Angeles        Member  Female  Orange Juice
#
#   product_category  unit_price  quantity   tax  total_price  reward_points
# 0    Personal Care        5.50         3  1.16        17.66              1
# 1       Stationery        2.75        10  1.93        29.43              0
# 2           Fruits        1.20        15  1.26        19.26              1
# 3        Household        7.80         5  2.73        41.73              0
# 4        Beverages        3.50         7  1.72        26.22              2

# %%
df.head(10)
# Out:
#    sale_id branch         city customer_type  gender  product_name  \
# 0        1      A     New York        Member    Male       Shampoo
# 1        2      B  Los Angeles        Normal  Female      Notebook
# 2        3      A     New York        Member  Female         Apple
# 3        4      A      Chicago        Normal    Male     Detergent
# 4        5      B  Los Angeles        Member  Female  Orange Juice
# 5        6      A      Chicago        Normal    Male       Shampoo
# 6        7      A      Chicago        Normal    Male       Shampoo
# 7        8      B  Los Angeles        Normal  Female       Shampoo
# 8        9      A      Chicago        Member  Female         Apple
# 9       10      B  Los Angeles        Member    Male       Shampoo
#
#   product_category  unit_price  quantity    tax  total_price  reward_points
# 0    Personal Care        5.50         3   1.16        17.66              1
# 1       Stationery        2.75        10   1.93        29.43              0
# ...

# %% [markdown]
# #🧠 Mind:
#
# head()
#
# ↓
#
# Dataset ke starting rows

# %% [markdown]
# #4️⃣ tail()
#
# ##Dataset ke last rows dekhne ke liye:

# %%
df.tail()
# Out:
#      sale_id branch      city customer_type  gender  product_name  \
# 995      996      A  New York        Member  Female       Shampoo
# 996      997      A  New York        Member    Male     Detergent
# 997      998      A  New York        Member  Female       Shampoo
# 998      999      A  New York        Member  Female       Shampoo
# 999     1000      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 995       Stationery        1.55        11  1.19        18.24              1
# 996    Personal Care        2.44         7  1.20        18.28              1
# 997       Stationery       17.92         2  2.51        38.35              3
# 998        Beverages       17.41         4  4.87        74.51              7
# 999       Stationery        4.11         4  1.15        17.59              0

# %%
df.tail(10)
# Out:
#      sale_id branch      city customer_type  gender  product_name  \
# 990      991      A   Chicago        Normal  Female     Detergent
# 991      992      A  New York        Normal    Male      Notebook
# 992      993      A  New York        Normal  Female         Apple
# 993      994      A  New York        Normal  Female  Orange Juice
# 994      995      A  New York        Member    Male      Notebook
# 995      996      A  New York        Member  Female       Shampoo
# 996      997      A  New York        Member    Male     Detergent
# 997      998      A  New York        Member  Female       Shampoo
# 998      999      A  New York        Member  Female       Shampoo
# 999     1000      A  New York        Normal    Male  Orange Juice
#
#     product_category  unit_price  quantity   tax  total_price  reward_points
# 990       Stationery        8.18         1  0.57         8.75              0
# 991        Household       11.33         9  7.14       109.11              0
# ...

# %% [markdown]
# #5️⃣ Dataset ka Size — shape

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.shape[0] #-> Rows
# Out:
# 1000

# %%
df.shape[1] #-> Columns
# Out:
# 12

# %% [markdown]
# #6️⃣ Column Names

# %%
df.columns
# Out:
# Index(['sale_id', 'branch', 'city', 'customer_type', 'gender', 'product_name',
#        'product_category', 'unit_price', 'quantity', 'tax', 'total_price',
#        'reward_points'],
#       dtype='object')

# %% [markdown]
# ####Agar List Chahiye:

# %%
df.columns.tolist()
# Out:
# ['sale_id',
#  'branch',
#  'city',
#  'customer_type',
#  'gender',
#  'product_name',
#  'product_category',
#  'unit_price',
#  'quantity',
#  'tax',
#  'total_price',
#  'reward_points']

# %% [markdown]
# #7️⃣ Dataset Information — info()
#
# ##Ye Day 34 ka sabse important function hai.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sale_id           1000 non-null   int64
#  1   branch            1000 non-null   object
#  2   city              1000 non-null   object
#  3   customer_type     1000 non-null   object
#  4   gender            1000 non-null   object
#  5   product_name      1000 non-null   object
#  6   product_category  1000 non-null   object
#  7   unit_price        1000 non-null   float64
#  8   quantity          1000 non-null   int64
#  9   tax               1000 non-null   float64
#  10  total_price       1000 non-null   float64
#  11  reward_points     1000 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 93.9+ KB

# %% [markdown]
# #8️⃣ Data Types

# %%
df.dtypes
# Out:
# sale_id               int64
# branch               object
# city                 object
# customer_type        object
# gender               object
# product_name         object
# product_category     object
# unit_price          float64
# quantity              int64
# tax                 float64
# total_price         float64
# reward_points         int64
# dtype: object

# %% [markdown]
# #9️⃣ Statistical Summary
#
# ##Numerical columns ke liye:

# %%
df.describe()
# Out:
#            sale_id   unit_price     quantity          tax  total_price  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    10.836110    10.337000     7.758010   118.583900
# std     288.819436     5.775924     6.029908     6.538066    99.936441
# min       1.000000     1.020000     1.000000     0.080000     1.210000
# 25%     250.750000     5.867500     5.000000     2.510000    38.380000
# 50%     500.500000    10.615000    10.000000     5.870000    89.705000
# 75%     750.250000    15.882500    16.000000    11.522500   176.072500
# max    1000.000000    20.980000    20.000000    28.390000   433.990000
#
#        reward_points
# count    1000.000000
# mean        6.057000
# std         9.350464
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        10.000000
# max        43.000000

# %% [markdown]
# #🔟 Missing Values

# %%
df.isnull()
# Out:
#      sale_id  branch   city  customer_type  gender  product_name  \
# 0      False   False  False          False   False         False
# 1      False   False  False          False   False         False
# 2      False   False  False          False   False         False
# 3      False   False  False          False   False         False
# 4      False   False  False          False   False         False
# ..       ...     ...    ...            ...     ...           ...
# 995    False   False  False          False   False         False
# 996    False   False  False          False   False         False
# 997    False   False  False          False   False         False
# 998    False   False  False          False   False         False
# 999    False   False  False          False   False         False
#
#      product_category  unit_price  quantity    tax  total_price  reward_points
# 0               False       False     False  False        False          False
# ...

# %%
df.isnull().sum()
# Out:
# sale_id             0
# branch              0
# city                0
# customer_type       0
# gender              0
# product_name        0
# product_category    0
# unit_price          0
# quantity            0
# tax                 0
# total_price         0
# reward_points       0
# dtype: int64

# %% [markdown]
# #1️⃣1️⃣ Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ###Actual duplicate rows dekhne ke liye:

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sale_id, branch, city, customer_type, gender, product_name, product_category, unit_price, quantity, tax, total_price, reward_points]
# Index: []

# %% [markdown]
# #1️⃣2️⃣ Unique Values
#
# ##Suppose dataset mein Category column hai:

# %%
df["branch"].unique()
# Out:
# array(['A', 'B'], dtype=object)

# %%
df["city"].unique()
# Out:
# array(['New York', 'Los Angeles', 'Chicago'], dtype=object)

# %%
df["customer_type"].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["product_category"].unique()
# Out:
# array(['Personal Care', 'Stationery', 'Fruits', 'Household', 'Beverages'],
#       dtype=object)

# %%
df["product_name"].unique()
# Out:
# array(['Shampoo', 'Notebook', 'Apple', 'Detergent', 'Orange Juice'],
#       dtype=object)

# %% [markdown]
# #1️⃣2️⃣ Number of Unique Values

# %%
print("Branches:", df["branch"].nunique())
print("Cities:", df["city"].nunique())
print("Customer Types:", df["customer_type"].nunique())
print("Gender:", df["gender"].nunique())
print("Product Categories:", df["product_category"].nunique())
print("Products:", df["product_name"].nunique())
# Out:
# Branches: 2
# Cities: 3
# Customer Types: 2
# Gender: 2
# Product Categories: 5
# Products: 5

# %% [markdown]
# #13️⃣ Value Counts
#
# ##Ab dekhte hain kitni sales kis branch se hain:

# %%
df["branch"].value_counts()
# Out:
# branch
# A    674
# B    326
# Name: count, dtype: int64

# %%
df["city"].value_counts()
# Out:
# city
# New York       344
# Chicago        330
# Los Angeles    326
# Name: count, dtype: int64

# %%
df["customer_type"].value_counts()
# Out:
# customer_type
# Member    516
# Normal    484
# Name: count, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      528
# Female    472
# Name: count, dtype: int64

# %%
df["product_category"].value_counts()
# Out:
# product_category
# Fruits           209
# Personal Care    208
# Stationery       198
# Household        198
# Beverages        187
# Name: count, dtype: int64

# %%
df["product_name"].value_counts()
# Out:
# product_name
# Shampoo         224
# Orange Juice    208
# Notebook        194
# Detergent       189
# Apple           185
# Name: count, dtype: int64

# %% [markdown]
# #14️⃣ Numerical columns ko samjho

# %%
df[[
    "unit_price",
    "quantity",
    "tax",
    "total_price",
    "reward_points"
]].describe()
# Out:
#         unit_price     quantity          tax  total_price  reward_points
# count  1000.000000  1000.000000  1000.000000  1000.000000    1000.000000
# mean     10.836110    10.337000     7.758010   118.583900       6.057000
# std       5.775924     6.029908     6.538066    99.936441       9.350464
# min       1.020000     1.000000     0.080000     1.210000       0.000000
# 25%       5.867500     5.000000     2.510000    38.380000       0.000000
# 50%      10.615000    10.000000     5.870000    89.705000       0.000000
# 75%      15.882500    16.000000    11.522500   176.072500      10.000000
# max      20.980000    20.000000    28.390000   433.990000      43.000000

# %% [markdown]
# #15️⃣ Total Business Metrics

# %% [markdown]
# ###Total Revenue:

# %%
df["total_price"].sum()
# Out:
# np.float64(118583.9)

# %% [markdown]
# ###Total Quantity Sold:

# %%
df["quantity"].sum()
# Out:
# np.int64(10337)

# %% [markdown]
# ###Average Transaction Value:

# %%
df["total_price"].mean()
# Out:
# np.float64(118.5839)

# %% [markdown]
# ###Highest Transaction:

# %%
df["total_price"].max()
# Out:
# 433.99

# %% [markdown]
# ###Lowest Transaction:

# %%
df["total_price"].min()
# Out:
# 1.21

# %% [markdown]
# ###Total Tax Collected:

# %%
df["tax"].sum()
# Out:
# np.float64(7758.01)

# %% [markdown]
# ###Total Reward Points:

# %%
df["reward_points"].sum()
# Out:
# np.int64(6057)

# %% [markdown]
# #16️⃣ Branch-wise Revenue
#
# ##Ab actual analysis start:

# %%
df.groupby("branch")["total_price"].sum()
# Out:
# branch
# A    82811.64
# B    35772.26
# Name: total_price, dtype: float64

# %% [markdown]
# ###Isse pata chalega:
#
# ###Har branch se kitni total sales hui.

# %% [markdown]
# #Quantity ke liye:

# %%
df.groupby("branch")["quantity"].sum()
# Out:
# branch
# A    6982
# B    3355
# Name: quantity, dtype: int64

# %% [markdown]
# #Average Transaction Ke Liye:

# %%
df.groupby("branch")["total_price"].mean()
# Out:
# branch
# A    122.865935
# B    109.730859
# Name: total_price, dtype: float64

# %% [markdown]
# #17️⃣ City-wise Revenue

# %%
df.groupby("city")["total_price"].sum()
# Out:
# city
# Chicago        42584.71
# Los Angeles    35772.26
# New York       40226.93
# Name: total_price, dtype: float64

# %% [markdown]
# #Aur Quantity:

# %%
df.groupby("city")["quantity"].sum()
# Out:
# city
# Chicago        3638
# Los Angeles    3355
# New York       3344
# Name: quantity, dtype: int64

# %% [markdown]
# #18️⃣ Product Category Analysis

# %%
df.groupby("product_category")["total_price"].sum()
# Out:
# product_category
# Beverages        22983.32
# Fruits           26197.45
# Household        21615.84
# Personal Care    27050.18
# Stationery       20737.11
# Name: total_price, dtype: float64

# %% [markdown]
# ##Quantity:

# %%
df.groupby("product_category")["quantity"].sum()
# Out:
# product_category
# Beverages        1952
# Fruits           2286
# Household        1908
# Personal Care    2278
# Stationery       1913
# Name: quantity, dtype: int64

# %% [markdown]
# ##Average Prices:

# %%
df.groupby("product_category")["unit_price"].mean()
# Out:
# product_category
# Beverages        11.113155
# Fruits           10.845263
# Household        10.930707
# Personal Care    11.246923
# Stationery       10.038636
# Name: unit_price, dtype: float64

# %% [markdown]
# #19️⃣ Customer Type Analysis

# %%
df.groupby("customer_type")["total_price"].sum()
# Out:
# customer_type
# Member    63213.63
# Normal    55370.27
# Name: total_price, dtype: float64

# %% [markdown]
# ##Aur Transaction Count:

# %%
df["customer_type"].value_counts()
# Out:
# customer_type
# Member    516
# Normal    484
# Name: count, dtype: int64

# %% [markdown]
# #20️⃣ Gender Analysis

# %%
df.groupby("gender")["total_price"].sum()
# Out:
# gender
# Female    54265.45
# Male      64318.45
# Name: total_price, dtype: float64

# %% [markdown]
# #🔥 21️⃣ Sabse useful — Ek saath multiple metrics
#
# ##Ye bahut important Pandas pattern hai:

# %%
df.groupby("product_category").agg({
    "total_price": "sum",
    "quantity": "sum",
    "unit_price": "mean",
    "tax": "sum"
})
# Out:
#                   total_price  quantity  unit_price      tax
# product_category
# Beverages            22983.32      1952   11.113155  1503.65
# Fruits               26197.45      2286   10.845263  1713.86
# Household            21615.84      1908   10.930707  1414.13
# Personal Care        27050.18      2278   11.246923  1769.66
# Stationery           20737.11      1913   10.038636  1356.71

# %% [markdown]
# #🧠 Day 34 ka actual conclusion
#
# ##Ab tumne dataset ko sirf inspect nahi kiya, balki basic business questions bhi answer karne start kar diye:
#
#
# Dataset
#
#    ↓
#
# Understand structure
#
#    ↓
#
# Check data quality
#
#    ↓
#
# Understand categories
#
#    ↓
#
# Calculate KPIs
#
#    ↓
#
# Compare branches
#
#    ↓
#
# Compare cities
#
#    ↓
#
# Compare products
#
#    ↓
#
# Understand customers
